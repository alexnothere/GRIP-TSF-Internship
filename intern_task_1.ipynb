# %% [markdown]
# ### GRIP AUG 2022 BATCH (#GRIPJULY22)
#
# ##### PROBLEM STATEMENT: Predict the percentage of a student based on the no. of study hours. What will be the predicted score if a student studies for 9.25 hrs/day?
#
# ### Name: Ashish Ashok Veer
#
# ##### Importing libraries to be used:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Dataset:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')

# %% [markdown]
# ### Visualization of DATA:

# %%
plt.scatter(x = df['Hours'], y = df['Scores'])
# plt.show()

# %% [markdown]
# ### Results and Feature separated:

# %%
X = df[["Hours"]]
y = df[["Scores"]]

# %%
X.shape
# Out:
# (25, 1)

# %%
y.shape
# Out:
# (25, 1)

# %% [markdown]
# ### Model Creation:

# %% [markdown]
# #### This problem is a simple Linear Regression problem, as we can see there is a proportionality between Marks in percentage and Time Studied in hrs.

# %% [markdown]
# #### First we will split the data in Test and Train sets:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 42)

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Applying the model to predict values:

# %%
regressor.predict([[9.25]])
# Out:
# c:\Users\ashwi\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[92.33571987]])

# %%
# plotting scatter plot 

line = regressor.coef_*X+regressor.intercept_

plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ### Conclusion:
#
# #### It was a simple Linear Regression problem which is Supervised Machine Learning Concept. This was the first task of GRIP|TSF - Data Anayltics and Business Analysis Internship.
#
# #### 92.34% if a student studies for 9.25 hrs/day.
